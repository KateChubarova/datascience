# %%
import seaborn as sns
import pandas as pd

# %%
path = 'https://stepik.org/media/attachments/lesson/779914/fen_train.csv'
train = pd.read_csv(path)

# Переводим датасет в long формат
df_melt = train.melt(
    id_vars="signal_id",
    value_vars=[f"p{i}" for i in range(1, 128 + 1)],
    var_name="orders",
    value_name="value",
).merge(train[["signal_id", "label"]], on="signal_id", how="left")

# Отбираем несколько примеров разных классов
tmp = df_melt[df_melt.signal_id.isin([3, 13, 16, 256])]

# Строим графику
sns.relplot(
    data=tmp,
    x="orders",
    y="value",
    hue="label",
    style="signal_id",
    kind="line",
    aspect=3,
).set_xticklabels(rotation=45, horizontalalignment="right", step=2);

# %%
import numpy as np

# %%
train
# Out:
#      signal_id        p1        p2        p3        p4        p5        p6  \
# 0            3 -0.177789 -0.081874 -0.096131 -0.099436 -0.098867 -0.105427
# 1            4  0.010337  0.010733  0.117607  0.259589  0.339589  0.329296
# 2            5 -0.221846 -0.247773 -0.187847 -0.181616 -0.108799 -0.099480
# 3            6  0.411835  0.513823  0.558802  0.380244  0.210830  0.174093
# 4            7  0.221770 -0.026863 -0.249447 -0.340728 -0.288676 -0.207364
# ..         ...       ...       ...       ...       ...       ...       ...
# 649       1214  0.411055  0.168638 -0.198538 -0.300685  0.056328  0.617390
# 650       1218  0.104295  0.109067  0.045116 -0.033823 -0.072836 -0.054253
# 651       1219 -0.104234 -0.085259 -0.043942 -0.030790  0.026148  0.028789
# 652       1221  0.031189  0.051451  0.176866  0.262605  0.201261  0.132246
# 653       1222 -0.002486 -0.063581 -0.082845 -0.089079 -0.089742 -0.067355
#
#            p7        p8        p9  ...      p120      p121      p122  \
# 0   -0.083472 -0.074000 -0.065275  ... -0.068265 -0.059327 -0.013739
# 1    0.281260  0.115658 -0.172955  ...  0.370135  0.344097  0.158927
# 2   -0.083244 -0.054944 -0.100919  ... -0.086089 -0.080394 -0.089625
# 3    0.102772 -0.051933 -0.237179  ...  0.113856  0.014483 -0.112094
# 4   -0.155768 -0.091768 -0.119012  ... -0.216549 -0.167078 -0.077491
# ..        ...       ...       ...  ...       ...       ...       ...
# 649  0.722862  0.370691 -0.013178  ... -0.244818 -0.192781 -0.172304
# 650 -0.014003  0.027218  0.054011  ... -0.016502 -0.022746 -0.041478
# 651  0.004455  0.058006  0.125277  ... -0.159490 -0.126357 -0.094226
# 652 -0.044051 -0.280172 -0.340040  ... -0.138272 -0.143904 -0.134502
# 653 -0.040855  0.014197  0.043075  ... -0.030031  0.112672  0.167329
#
#          p123      p124      p125      p126      p127      p128  label
# 0    0.009359  0.009645  0.070163  0.108443  0.127638  0.099169      0
# 1   -0.102145 -0.301141 -0.148649  0.263631  0.480440  0.420327      0
# 2   -0.122950 -0.074273 -0.018595  0.054752  0.097544  0.067837      0
# 3   -0.133700 -0.024104 -0.042590 -0.062838 -0.078137 -0.194478      0
# 4   -0.115439 -0.126838 -0.087323 -0.115734 -0.102995 -0.098657      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 649 -0.145502 -0.125380 -0.012973  0.055567  0.017957  0.104189      0
# 650 -0.011162 -0.018928 -0.004817  0.032872  0.027806  0.033331      0
# 651 -0.072689 -0.132456 -0.135855 -0.079241 -0.015215  0.021913      0
# 652 -0.112658 -0.045430  0.038033  0.091223  0.180421  0.522160      0
# 653  0.109314  0.058961  0.213755  0.328230  0.260852  0.234161      0
#
# [654 rows x 130 columns]

# %%
train['label'].hist()
# Out:
# <Axes: >

# %%
train.drop([''])
