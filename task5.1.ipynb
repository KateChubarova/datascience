# %%
import pandas as pd
path = 'https://stepik.org/media/attachments/lesson/779914/make_it_easy.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#       feature_1  feature_2  feature_3 label
# 0           2.5       0.00         58     B
# 1           2.5       0.02         61     B
# 2           2.5       0.05         33     B
# 3           2.5       0.07         89     B
# 4           2.5       0.10         58     B
# ...         ...        ...        ...   ...
# 1253        2.0      -0.09         30     A
# 1254        2.0      -0.07         41     A
# 1255        2.0      -0.05         30     A
# 1256        2.0      -0.03          3     A
# 1257        2.0      -0.01         36     A
#
# [1258 rows x 4 columns]

# %%
df['label'].nunique()
# Out:
# 2

# %%
df['feature_3']
# Out:
# 0       58
# 1       61
# 2       33
# 3       89
# 4       58
#         ..
# 1253    30
# 1254    41
# 1255    30
# 1256     3
# 1257    36
# Name: feature_3, Length: 1258, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['feature_1'], df['feature_2'], marker='o', linestyle='-')

# %%
plt.plot(df['feature_1'], df['label'], marker='o', linestyle='-')

# %%
plt.plot(df['feature_1'], df['feature_3'], marker='o', linestyle='-')

# %%
plt.plot(df['feature_2'], df['feature_3'], marker='o', linestyle='-')

# %%
plt.plot(df['feature_1'], df['feature_3'], marker='o', linestyle='-')

# %%
plt.plot(df['feature_3'], df['label'], marker='o', linestyle='-')

# %%
plt.plot(df['feature_1'], df['label'], marker='o', linestyle='-')

# %%
plt.plot(df['feature_2'], df['label'], marker='o', linestyle='-')

# %%
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, hue='label')
plt.show()

# %%
df['killer_feature'] = (df['feature_1']**2 + df['feature_2']**2)**0.5

# %%
df
# Out:
#       feature_1  feature_2  feature_3 label  killer_feature
# 0           2.5       0.00         58     B        2.500000
# 1           2.5       0.02         61     B        2.500080
# 2           2.5       0.05         33     B        2.500500
# 3           2.5       0.07         89     B        2.500980
# 4           2.5       0.10         58     B        2.501999
# ...         ...        ...        ...   ...             ...
# 1253        2.0      -0.09         30     A        2.002024
# 1254        2.0      -0.07         41     A        2.001225
# 1255        2.0      -0.05         30     A        2.000625
# 1256        2.0      -0.03          3     A        2.000225
# 1257        2.0      -0.01         36     A        2.000025
#
# [1258 rows x 5 columns]

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'feature_1'}>,
#         <Axes: title={'center': 'feature_2'}>],
#        [<Axes: title={'center': 'feature_3'}>,
#         <Axes: title={'center': 'killer_feature'}>]], dtype=object)
