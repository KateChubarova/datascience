# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_10.csv')

# Учтите, что new_index, new_data, del_index_list, index в тестовой системе будут иметь другие значения
new_index = 50
new_data = ['new_car_id', 'new_worker_id', '2019-11-11 4:44','refuel_check', 3.5, 10]
del_index_list = [41, 18, 33, 7, 46]
index = 22


# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_10_ans.csv')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df.loc[new_index] = new_data

# %%
df
# Out:
#         car_id      worker_id          fix_date     work_type  destroy_degree  \
# 0   C-8860661H             BM    2020-1-5 13:17     reparking             1.0
# 1   Z76775340d             IL    2020-5-25 5:26        repair             8.4
# 2   r12485993Y             HN   2020-10-15 1:11     reparking             1.0
# 3   Z-1382353b             VX  2019-11-17 14:38        repair             5.7
# 4   p14707024B             JP   2019-11-23 3:44  refuel_check             1.0
# 5   f-1883871J             LJ    2019-2-12 2:42        repair             5.5
# 6   F-1518753o             ET     2019-4-2 13:9        repair             5.0
# 7   y75359172F             HX     2020-9-21 4:0     reparking             1.0
# 8   F13192545Q             UY      2019-5-3 3:1        repair             4.3
# 9   H12617664T             MV    2020-1-22 7:36  refuel_check             1.0
# 10  V-2109665o             DH    2018-2-19 6:11        repair             4.9
# 11  L45819441T             ND   2019-6-19 21:50        repair             3.9
# 12  z48466812V             OX    2021-10-4 2:36     reparking             1.0
# 13  e-2154304r             RT     2020-4-24 1:4     reparking             1.0
# 14  Q-3414660J             SZ    2018-8-4 21:47        repair             4.6
# 15  n-2248103n             JL    2020-9-9 11:14     reparking             1.0
# 16  o90119190V             ZY   2019-11-24 11:4     reparking             1.0
# 17  K-1010636S             KB    2021-2-21 6:16        repair             5.2
# 18  U-1696081V             JO     2019-11-3 4:1     reparking            10.0
# 19  h-1344515n             YJ   2019-4-15 20:53     reparking             1.0
# 20  b-1448976u             QW     2019-3-22 1:9        repair             6.9
# 21  E-1829228V             MD   2019-2-22 14:34        repair             3.8
# 22  m-8965256V             XS     2020-7-20 2:8  refuel_check             1.0
# 23  I-1538597J             RC   2019-6-17 19:45        repair             5.8
# 24  n28625799A             WP   2019-2-15 21:31        refuel             1.0
# 25  b-4266665E             MZ   2020-11-12 0:10     reparking             1.0
# 26  v-1209318r             QN    2020-5-18 4:51     reparking             1.0
# 27  h12427301o             WN   2019-9-24 19:33        refuel             1.0
# 28  z-7198780T             RN     2020-1-9 3:13        repair            10.0
# 29  b-1441595E             SG   2019-4-21 11:41        repair             4.5
# 30  n31468349R             VW   2019-2-12 20:34     reparking             1.0
# 31  Z95207161f             UJ    2020-4-22 5:19        repair            10.0
# 32  n31468349R             IP  2019-11-23 11:48     reparking             8.0
# 33  V24408620j             XF    2018-2-2 11:15        repair             4.9
# 34  a10698807I             CS  2020-11-23 15:33        repair             7.0
# 35  p81056764h             VY    2017-5-27 18:1     reparking             1.0
# 36  K-1436228o             QH     2020-8-3 19:1        repair             5.0
# 37  P62164543W             HC    2020-9-30 0:36        repair             6.8
# 38  c-1411220k             IJ    2019-5-3 20:37        refuel             1.0
# 39  B13169162p             CY    2020-6-28 6:25     reparking             9.0
# 40  j51305093b             HP     2019-2-29 7:0     reparking             1.0
# 41  p13496102g             TS   2020-4-19 22:47        refuel             1.0
# 42  v34523863p             FN    2019-9-4 14:36     reparking             1.0
# 43  H97221372X             OW    2019-7-28 0:25  refuel_check             1.0
# 44  l17843143j             XN    2019-2-28 21:7        repair             5.5
# 45  j-1549044A             ZF     2020-6-17 3:1        refuel             5.0
# 46  O23192334Z             CN    2020-4-14 8:48     reparking             1.0
# 47  B18597537S             NR   2019-8-16 19:51     reparking             1.0
# 48  H29930196K             NF   2019-3-24 22:47        repair             5.0
# 49  p-2255017N             MN   2019-11-11 5:51        repair             7.7
# 50  new_car_id  new_worker_id   2019-11-11 4:44  refuel_check             3.5
#
#     work_duration
# 0              28
# 1              48
# 2              21
# 3              13
# 4              21
# 5              25
# 6              17
# 7              23
# 8              10
# 9              26
# 10             14
# 11              3
# 12             21
# 13             20
# 14             10
# 15             29
# 16             27
# 17             17
# 18             66
# 19             26
# 20             39
# 21              5
# 22             20
# 23             22
# 24             26
# 25             17
# 26             22
# 27             28
# 28             48
# 29              3
# 30             24
# 31             48
# 32             41
# 33              9
# 34             27
# 35             29
# 36             14
# 37             34
# 38             27
# 39             53
# 40             28
# 41             22
# 42             31
# 43             17
# 44             19
# 45             47
# 46             23
# 47             26
# 48             15
# 49             42
# 50             10

# %%
df = df.drop(del_index_list, axis=0)

# %%
df.loc[df.index == index, 'destroy_degree'] += 1

# %%
df = df.drop('fix_date', axis=1)

# %%
df['efficient'] = df['destroy_degree']/df['work_duration']

# %%
df['work_duration'] = df['work_duration']**2

# %%
df.rename(columns = {'work_duration':'work_duration_square'}, inplace=True)

# %%
df.drop_duplicates(subset=['car_id'], inplace=True)

# %%
df
# Out:
#         car_id      worker_id     work_type  destroy_degree  \
# 0   C-8860661H             BM     reparking             1.0
# 1   Z76775340d             IL        repair             8.4
# 2   r12485993Y             HN     reparking             1.0
# 3   Z-1382353b             VX        repair             5.7
# 4   p14707024B             JP  refuel_check             1.0
# 5   f-1883871J             LJ        repair             5.5
# 6   F-1518753o             ET        repair             5.0
# 8   F13192545Q             UY        repair             4.3
# 9   H12617664T             MV  refuel_check             1.0
# 10  V-2109665o             DH        repair             4.9
# 11  L45819441T             ND        repair             3.9
# 12  z48466812V             OX     reparking             1.0
# 13  e-2154304r             RT     reparking             1.0
# 14  Q-3414660J             SZ        repair             4.6
# 15  n-2248103n             JL     reparking             1.0
# 16  o90119190V             ZY     reparking             1.0
# 17  K-1010636S             KB        repair             5.2
# 19  h-1344515n             YJ     reparking             1.0
# 20  b-1448976u             QW        repair             6.9
# 21  E-1829228V             MD        repair             3.8
# 22  m-8965256V             XS  refuel_check             2.0
# 23  I-1538597J             RC        repair             5.8
# 24  n28625799A             WP        refuel             1.0
# 25  b-4266665E             MZ     reparking             1.0
# 26  v-1209318r             QN     reparking             1.0
# 27  h12427301o             WN        refuel             1.0
# 28  z-7198780T             RN        repair            10.0
# 29  b-1441595E             SG        repair             4.5
# 30  n31468349R             VW     reparking             1.0
# 31  Z95207161f             UJ        repair            10.0
# 34  a10698807I             CS        repair             7.0
# 35  p81056764h             VY     reparking             1.0
# 36  K-1436228o             QH        repair             5.0
# 37  P62164543W             HC        repair             6.8
# 38  c-1411220k             IJ        refuel             1.0
# 39  B13169162p             CY     reparking             9.0
# 40  j51305093b             HP     reparking             1.0
# 42  v34523863p             FN     reparking             1.0
# 43  H97221372X             OW  refuel_check             1.0
# 44  l17843143j             XN        repair             5.5
# 45  j-1549044A             ZF        refuel             5.0
# 47  B18597537S             NR     reparking             1.0
# 48  H29930196K             NF        repair             5.0
# 49  p-2255017N             MN        repair             7.7
# 50  new_car_id  new_worker_id  refuel_check             3.5
#
#     work_duration_square  efficient
# 0                    784   0.035714
# 1                   2304   0.175000
# 2                    441   0.047619
# 3                    169   0.438462
# 4                    441   0.047619
# 5                    625   0.220000
# 6                    289   0.294118
# 8                    100   0.430000
# 9                    676   0.038462
# 10                   196   0.350000
# 11                     9   1.300000
# 12                   441   0.047619
# 13                   400   0.050000
# 14                   100   0.460000
# 15                   841   0.034483
# 16                   729   0.037037
# 17                   289   0.305882
# 19                   676   0.038462
# 20                  1521   0.176923
# 21                    25   0.760000
# 22                   400   0.100000
# 23                   484   0.263636
# 24                   676   0.038462
# 25                   289   0.058824
# 26                   484   0.045455
# 27                   784   0.035714
# 28                  2304   0.208333
# 29                     9   1.500000
# 30                   576   0.041667
# 31                  2304   0.208333
# 34                   729   0.259259
# 35                   841   0.034483
# 36                   196   0.357143
# 37                  1156   0.200000
# 38                   729   0.037037
# 39                  2809   0.169811
# 40                   784   0.035714
# 42                   961   0.032258
# 43                   289   0.058824
# 44                   361   0.289474
# 45                  2209   0.106383
# 47                   676   0.038462
# 48                   225   0.333333
# 49                  1764   0.183333
# 50                   100   0.350000

# %%
ans
# Out:
#     Unnamed: 0      car_id      worker_id     work_type  destroy_degree  \
# 0            0  C-8860661H             BM     reparking             1.0
# 1            1  Z76775340d             IL        repair             8.4
# 2            2  r12485993Y             HN     reparking             1.0
# 3            3  Z-1382353b             VX        repair             5.7
# 4            4  p14707024B             JP  refuel_check             1.0
# 5            5  f-1883871J             LJ        repair             5.5
# 6            6  F-1518753o             ET        repair             5.0
# 7            8  F13192545Q             UY        repair             4.3
# 8            9  H12617664T             MV  refuel_check             1.0
# 9           10  V-2109665o             DH        repair             4.9
# 10          11  L45819441T             ND        repair             3.9
# 11          12  z48466812V             OX     reparking             1.0
# 12          13  e-2154304r             RT     reparking             1.0
# 13          14  Q-3414660J             SZ        repair             4.6
# 14          15  n-2248103n             JL     reparking             1.0
# 15          16  o90119190V             ZY     reparking             1.0
# 16          17  K-1010636S             KB        repair             5.2
# 17          19  h-1344515n             YJ     reparking             1.0
# 18          20  b-1448976u             QW        repair             6.9
# 19          21  E-1829228V             MD        repair             3.8
# 20          22  m-8965256V             XS  refuel_check             2.0
# 21          23  I-1538597J             RC        repair             5.8
# 22          24  n28625799A             WP        refuel             1.0
# 23          25  b-4266665E             MZ     reparking             1.0
# 24          26  v-1209318r             QN     reparking             1.0
# 25          27  h12427301o             WN        refuel             1.0
# 26          28  z-7198780T             RN        repair            10.0
# 27          29  b-1441595E             SG        repair             4.5
# 28          30  n31468349R             VW     reparking             1.0
# 29          31  Z95207161f             UJ        repair            10.0
# 30          34  a10698807I             CS        repair             7.0
# 31          35  p81056764h             VY     reparking             1.0
# 32          36  K-1436228o             QH        repair             5.0
# 33          37  P62164543W             HC        repair             6.8
# 34          38  c-1411220k             IJ        refuel             1.0
# 35          39  B13169162p             CY     reparking             9.0
# 36          40  j51305093b             HP     reparking             1.0
# 37          42  v34523863p             FN     reparking             1.0
# 38          43  H97221372X             OW  refuel_check             1.0
# 39          44  l17843143j             XN        repair             5.5
# 40          45  j-1549044A             ZF        refuel             5.0
# 41          47  B18597537S             NR     reparking             1.0
# 42          48  H29930196K             NF        repair             5.0
# 43          49  p-2255017N             MN        repair             7.7
# 44          50  new_car_id  new_worker_id  refuel_check             3.5
#
#     work_duration_square  efficient
# 0                    784   0.035714
# 1                   2304   0.175000
# 2                    441   0.047619
# 3                    169   0.438462
# 4                    441   0.047619
# 5                    625   0.220000
# 6                    289   0.294118
# 7                    100   0.430000
# 8                    676   0.038462
# 9                    196   0.350000
# 10                     9   1.300000
# 11                   441   0.047619
# 12                   400   0.050000
# 13                   100   0.460000
# 14                   841   0.034483
# 15                   729   0.037037
# 16                   289   0.305882
# 17                   676   0.038462
# 18                  1521   0.176923
# 19                    25   0.760000
# 20                   400   0.100000
# 21                   484   0.263636
# 22                   676   0.038462
# 23                   289   0.058824
# 24                   484   0.045455
# 25                   784   0.035714
# 26                  2304   0.208333
# 27                     9   1.500000
# 28                   576   0.041667
# 29                  2304   0.208333
# 30                   729   0.259259
# 31                   841   0.034483
# 32                   196   0.357143
# 33                  1156   0.200000
# 34                   729   0.037037
# 35                  2809   0.169811
# 36                   784   0.035714
# 37                   961   0.032258
# 38                   289   0.058824
# 39                   361   0.289474
# 40                  2209   0.106383
# 41                   676   0.038462
# 42                   225   0.333333
# 43                  1764   0.183333
# 44                   100   0.350000
